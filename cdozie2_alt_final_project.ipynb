# %% [markdown]
# # Clint Dozier BDI-475 Final Project
# *Examining State of Illinois Employee Salaries Under The IL Central Management System (CMS), 2011-2021*

# %%
# IMPORT STATEMENTS
import pandas as pd
import numpy as np
import plotly
import plotly.express as px
import plotly.graph_objects as go

# plotly.io is a low-level interface for interacting with figures/
# plotly.io.templates lists available plotly templates
# https://plotly.com/python-api-reference/plotly.io.html
import plotly.io as pio

#pd.set_option('display.max_columns', 50)

# %%
# Read in the dataset

df = pd.read_csv('/content/drive/MyDrive/Spring 2021/BDI-475/il_employee_salaries_since_2011.csv')

# Delete redundant column

del df['_id']

df
# Out:
#                                               Id  ...  Military Veteran
# 0       E66E4A4E767B69A7985744A673FD68AE59C9BCE3  ...                NO
# 1       B1C52532026C0EE32F21B60D4F76E9947CD47AAF  ...                NO
# 2       4F7CD61A17B87FB5062A02C79DFE795588295847  ...                NO
# 3       CC3EC019C668B48ED6C09BF1F18407787670A522  ...                NO
# 4       374B2A4CA9AC783EB415BA5E4B93908B1D0DBCC9  ...               YES
# ...                                          ...  ...               ...
# 183949  F62AFA20EF8110AB7F88507CF54EE77D7E11ABB3  ...                NO
# 183950  4E5E4401E79B4B38888B8DCC6502002281315088  ...                NO
# 183951  806D8D09A6BC4E662DBFD4DE06EC4902EE5827D0  ...                NO
# 183952  4D8FA26D4FA17E0C2604CD80D74FDC8B5F1D052C  ...                NO
# 183953  A18D469830FFAF1ADC8AAA318463BCD1AC3FC5BE  ...                NO
#
# [183954 rows x 14 columns]

# %%
df.shape
# Out:
# (183954, 14)

# %% [markdown]
# This dataset contains 183,954 rows and 14 columns, and spans the course of 10 years, from 2011 to now.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183954 entries, 0 to 183953
# Data columns (total 14 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Id                   183954 non-null  object
#  1   Year                 183954 non-null  int64
#  2   Agency               183954 non-null  object
#  3   Agency Division      183570 non-null  object
#  4   Employee Name        183954 non-null  object
#  5   Position Title       183838 non-null  object
#  6   Period Pay Rate      183954 non-null  int64
#  7   YTD Gross            183954 non-null  int64
#  8   Work County          183954 non-null  object
#  9   Rutan Exempt         183954 non-null  object
#  10  Collective or Merit  183954 non-null  object
#  11  4(d) Exempt          183954 non-null  object
#  12  Employment Status    183950 non-null  object
#  13  Military Veteran     183954 non-null  object
# dtypes: int64(3), object(11)
# memory usage: 19.6+ MB

# %%
# Group by YEAR and MEDIAN PERIOD PAY RATE

df_med_by_year = df.groupby('Year', as_index=False).agg({
    'Period Pay Rate': 'median'
}).rename(columns={
    'Period Pay Rate': 'Median Period Pay Rate'
})
df_med_by_year = df_med_by_year.sort_values(by='Median Period Pay Rate')

df_med_by_year
# Out:
#     Year  Median Period Pay Rate
# 0   2011                    2000
# 1   2012                    2100
# 4   2015                    2200
# 5   2016                    2200
# 6   2017                    2200
# 7   2018                    2200
# 2   2013                    2300
# 3   2014                    2300
# 8   2019                    2300
# 9   2020                    2500
# 10  2021                    2600

# %%
# Distribution of Median Salaries by YEAR

fig1 = px.bar(df_med_by_year,
              x="Year",
              y="Median Period Pay Rate",
              template='plotly_dark',
              height = 800,
              title = 'Distribution of Median Salaries by Year'
              )

fig1
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="43b953b0-f585-417c-ae5d-47ea7148b5ca" class="plotly-graph-div" style="height:800px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("43b953b0-f585-417c-ae5d-47ea7148b5ca")) {
#                     Plotly.newPlot(
#                         '43b953b0-f585-417c-ae5d-47ea7148b5ca',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Year=%{x}<br>Median Period Pay Rate=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": [2011, 2012, 2015, 2016, 2017, 2018, 2013, 2014, 2019, 2020, 2021], "xaxis": "x", "y": [2000, 2100, 2200, 2200, 2200, 2200, 2300, 2300, 2300, 2500, 2600], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 800, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"line": {"color": "#283442"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"line": {"color": "#283442"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "sc ...

# %%
# Group by YEAR and AVG PERIOD PAY RATE

df_avg_by_year = df.groupby('Year', as_index=False).agg({
    'Period Pay Rate': 'mean'
}).rename(columns={
    'Period Pay Rate': 'Average Period Pay Rate'
})
df_avg_by_year = df_avg_by_year.sort_values(by='Average Period Pay Rate')

df_avg_by_year
# Out:
#     Year  Average Period Pay Rate
# 0   2011              2049.547632
# 1   2012              2265.361680
# 5   2016              2346.570117
# 6   2017              2351.680450
# 4   2015              2360.071185
# 7   2018              2363.033096
# 2   2013              2394.744504
# 3   2014              2474.179871
# 8   2019              2591.938604
# 9   2020              2635.484492
# 10  2021              2712.894084

# %%
# Distribution of Avg Salaries by Year

fig2 = px.bar(df_avg_by_year,
              x="Year",
              y="Average Period Pay Rate",
              template='plotly_dark',
              height = 800,
              title = 'Distribution of Average Salaries by Year'
              )

fig2
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f02877a2-72df-458f-9495-3fce679b4b31" class="plotly-graph-div" style="height:800px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f02877a2-72df-458f-9495-3fce679b4b31")) {
#                     Plotly.newPlot(
#                         'f02877a2-72df-458f-9495-3fce679b4b31',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Year=%{x}<br>Average Period Pay Rate=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": [2011, 2012, 2016, 2017, 2015, 2018, 2013, 2014, 2019, 2020, 2021], "xaxis": "x", "y": [2049.5476317189996, 2265.3616800622244, 2346.57011702334, 2351.680449533503, 2360.071184717077, 2363.033095936322, 2394.744504294657, 2474.179870564606, 2591.9386044111957, 2635.4844917727814, 2712.8940843074743], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 800, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"line": {"color": "#283442"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"line": {"color": "#283442"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "sc ...

# %% [markdown]
# Very interesting from both of these datasets. We can see that both median and average state of Illinois employee salaries remained entirely falt from 2015 through 2018. This timeframe coincides when Bruce Rauner, who was critical of state employee benefits that he deemed as overly generous, was Governor of Illinois.

# %%
# Group by AGENCY and MEDIAN PERIOD PAY RATE

df_agency_med = df.groupby('Agency', as_index=False).agg({
    'Period Pay Rate': 'median'
}).rename(columns={
    'Period Pay Rate': 'Median Period Pay Rate'
})
df_agency_med = df_agency_med.sort_values(by='Median Period Pay Rate')

df_agency_med
# Out:
#                             Agency  Median Period Pay Rate
# 58                    RACING BOARD                    1600
# 55           PRISONER REVIEW BOARD                    1600
# 31      IL COMMUNITY COLLEGE BOARD                    1800
# 51                MILITARY AFFAIRS                    2000
# 25    HEALTHCARE & FAMILY SERVICES                    2000
# ..                             ...                     ...
# 15  COUNCIL ON DEVELOPMENTAL DISAB                    4000
# 44           ILLINOIS POWER AGENCY                    4100
# 39      IL STATE TOLL HIGHWAY AUTH                    4200
# 8         CIVIL SERVICE COMMISSION                    4800
# 62        STATE BOARD OF ELECTIONS                    4900
#
# [71 rows x 2 columns]

# %%
# Distribution of Median Salaries by Agency

fig3 = px.bar(df_agency_med,
              x="Agency",
              y="Median Period Pay Rate",
              template='plotly_dark',
              color='Median Period Pay Rate',
              color_continuous_scale = ['LightBlue', 'DodgerBlue'],
              height = 800,
              title = 'Distribution of Median Pay Rates by IL State Agency'
              )

fig3
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3c2693ae-8e20-4176-97bf-77c976b079ad" class="plotly-graph-div" style="height:800px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3c2693ae-8e20-4176-97bf-77c976b079ad")) {
#                     Plotly.newPlot(
#                         '3c2693ae-8e20-4176-97bf-77c976b079ad',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Agency=%{x}<br>Median Period Pay Rate=%{marker.color}", "legendgroup": "", "marker": {"color": [1600, 1600, 1800, 2000, 2000, 2000, 2000, 2050, 2100, 2100, 2100, 2100, 2100, 2200, 2200, 2200, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2400, 2400, 2450, 2500, 2500, 2500, 2500, 2600, 2600, 2600, 2600, 2600, 2600, 2600, 2700, 2700, 2700, 2700, 2700, 2750, 2800, 2800, 2800, 2900, 2900, 3000, 3000, 3100, 3100, 3100, 3200, 3200, 3250, 3300, 3400, 3500, 3600, 3700, 3700, 3700, 3800, 3800, 4000, 4100, 4200, 4800, 4900], "coloraxis": "coloraxis"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["RACING BOARD", "PRISONER REVIEW BOARD", "IL COMMUNITY COLLEGE BOARD", "MILITARY AFFAIRS", "HEALTHCARE & FAMILY SERVICES", "REVENUE", "VETERANS' AFFAIRS", "IL VIOLENCE PREVENTION AUTH", "SECRETARY OF STATE", "STATE POLICE MERIT BOARD", "HUMAN SERVICES", "STATE EMPLOYEES' RETIRE SYSTEM", "GOVERNOR'S OFF OF MGT & BUDGET", "NATURAL RESOURCES", "AGRICULTURE", "HUMAN RIGHTS", "STATE BOARD OF EDUCATION", "STATE LOTTERY", "STATE POLICE", "IL STUDENT ASSISTANCE COMM", "TEACHERS' RETIREMENT SYSTEM", "ABE LINCOLN PRES LIBRARY & MUS", "CORRECTIONS", "EMPLOYMENT SECURITY", "COMMISSION ON HUMAN RIGHTS", "INSURANCE", "DEAF & HARD OF HEARING COMM", "ENVIRONMENTAL PROTECT AGENCY", "IL CRIMINAL JUSTICE INFO AUTH", "CHILDREN AND FAMILY SERVICES", "ATTORNEY GENERAL", "HISTORIC PRESERVATION AGENCY", "IL ARTS COUNCIL", "JUVENILE JUSTICE", "IL EMERGENCY MANAGEMENT AGCY", "TRANSPORTATION", "PROPERTY TAX APPEAL BOARD", "OFFICE OF INSPECTOR GENERAL", "AGING", "CENTRAL MANAGEMENT", "LIQUOR CONTROL COMM", "LABOR", "FINANCIAL AND PROFESSIONAL REG", "BOARD OF HIGHER EDUCATION", "IL LABOR RELATIONS BOARD", "GUARDIAN & ADVOCACY COMM", "IL STATE BOARD OF INVESTMENTS", "PUBLIC HEALTH", "CAPITAL DEVELOPMENT BOARD", "OFFICE OF THE STATE FIRE MARSH", "CORONER TRAINING BOARD", "IL COMMERCE COMMISSION", "TREASURER", "EXECUTIVE ETHICS COMMISSION", "INNOVATION AND TECHNOLOGY", "IL EDUCAT LABOR RELATIONS BD", "COMPREHNSIVE HLTH INSURANCE BD", "COMMERCE AND ECONOMIC OPPORTUN", "IL LAW ENFORCE TRAIN & STDS BD", "HEALTH INFO EXCHANGE AUTH", "COMPTROLLER", "ILLINOIS GAMING BOARD", "IL WORKERS' COMPENSATION COMMI", "IL INDEPENDENT TAX TRIBUNAL", "LIEUTENANT GOVERNOR", "GOVERNOR", "COUNCIL ON DEVELOPMENTAL DISAB", "ILLINOIS POWER AGENCY", "IL STATE TOLL HIGHWAY AUTH", "CIVIL SERVICE COMMISSION", "STATE BOARD OF ELECTIONS"], "xaxis": "x", "y": [1600, 1600, 1800, 2000, 2000, 2000, 2000, 2050, 2100, 2100, 2100, 2100, 2100, 2200, 2200, 2200, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2400, 2400, 2450, 2500, 2500, 2500, 2500, 2600, 2600, 2600, 2600, 2600, 2600, 2600, 2700, 2700, 2700, 2700, 2700, 2750, 2800, 2800, 2800, 2900, 2900, 3000, 3000, 3100, 3100, 3100, 3200, 3200, 3250, 3300, 3400, 3500, 3600, 3700, 3700, 3700, 3800, 3800, 4000, 4100, 4200, 4800, 4900], "yaxis": "y"}],
#                         {"barmode": "relative", "coloraxis": {"colorbar": {"title": {"text": "Median Period Pay Rate"}}, "colorscale": [[0.0, "LightBlue"], [1.0, "DodgerBlue"]]}, "height": 800, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"line": {"color": "#283442"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"line": {"color": "#283442"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, ...

# %%
# Group by COUNTY and MEDIAN PERIOD PAY RATE

df_county_med = df.groupby('Work County', as_index=False).agg({
    'Period Pay Rate': 'median'
}).rename(columns={
    'Period Pay Rate': 'Median Period Pay Rate'
})
df_county_med = df_county_med.sort_values(by='Median Period Pay Rate')

df_county_med
# Out:
#    Work County  Median Period Pay Rate
# 43    KANKAKEE                    1800
# 30    HAMILTON                    1800
# 77      PUTNAM                    1850
# 75        POPE                    1900
# 0        ADAMS                    2000
# ..         ...                     ...
# 19     DE WITT                    2700
# 40  JO DAVIESS                    2800
# 96       WAYNE                    2800
# 3        BOONE                    3200
# 6      CALHOUN                    3200
#
# [103 rows x 2 columns]

# %%
# Distribution of Median Salaries by County

fig4 = px.bar(df_county_med,
              x="Work County",
              y="Median Period Pay Rate",
              template='plotly_dark',
              color='Median Period Pay Rate',
              color_continuous_scale = ['LightBlue', 'DodgerBlue'],
              height = 800,
              title = 'Distribution of Median Pay Rates by IL County'
              )

fig4
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9a0731d2-d65d-44a5-95f3-5615682244be" class="plotly-graph-div" style="height:800px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9a0731d2-d65d-44a5-95f3-5615682244be")) {
#                     Plotly.newPlot(
#                         '9a0731d2-d65d-44a5-95f3-5615682244be',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Work County=%{x}<br>Median Period Pay Rate=%{marker.color}", "legendgroup": "", "marker": {"color": [1800, 1800, 1850, 1900, 2000, 2000, 2000, 2100, 2100, 2100, 2100, 2200, 2200, 2200, 2200, 2200, 2200, 2200, 2200, 2200, 2200, 2200, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2400, 2400, 2400, 2400, 2400, 2400, 2400, 2400, 2400, 2400, 2400, 2400, 2400, 2400, 2400, 2400, 2400, 2400, 2400, 2400, 2400, 2450, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2550, 2600, 2600, 2600, 2600, 2600, 2600, 2600, 2600, 2600, 2600, 2600, 2600, 2700, 2700, 2700, 2800, 2800, 3200, 3200], "coloraxis": "coloraxis"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["KANKAKEE", "HAMILTON", "PUTNAM", "POPE", "ADAMS", "UNION", "PULASKI", "MASON", "MCDONOUGH", "MENARD", "EDGAR", "MCHENRY", "RICHLAND", "MASSAC", "SCHUYLER", "LAKE", "LA SALLE", "WABASH", "HARDIN", "PERRY", "LIVINGSTON", "CLINTON", "CASS", "MACON", "LASALLE", "COLES", "MACOUPIN", "KNOX", "SHELBY", "MADISON", "MARION", "ST CLAIR", "JEFFERSON", "JASPER", "LEE", "JACKSON", "CLAY", "SANGAMON", "DE KALB", "ROCK ISLAND", "BROWN", "FULTON", "MONTGOMERY", "MORGAN", "FAYETTE", "RANDOLPH", "VERMILION", "MCLEAN", "CHAMPAIGN", "MARSHALL", "OGLE", "LOGAN", "CHRISTIAN", "LAWRENCE", "WILLIAMSON", "EFFINGHAM", "FORD", "FRANKLIN", "WINNEBAGO", "ALEXANDER", "CUMBERLAND", "TAZEWELL", "JOHNSON", "KANE", "CRAWFORD", "PEORIA", "HENRY", "COOK", "GREENE", "SALINE", "WHITESIDE", "WILL", "CARROLL", "DUPAGE", "WOODFORD", "OUT OF STATE", "HANCOCK", "MOULTRIE", "DOUGLAS", "CLARK", "KENDALL", "JERSEY", "PIATT", "WARREN", "GRUNDY", "WHITE", "WASHINGTON", "HENDERSON", "BOND", "PIKE", "ST. CLAIR", "SCOTT", "MONROE", "BUREAU", "STEPHENSON", "STARK", "IROQUOIS", "MERCER", "DE WITT", "JO DAVIESS", "WAYNE", "BOONE", "CALHOUN"], "xaxis": "x", "y": [1800, 1800, 1850, 1900, 2000, 2000, 2000, 2100, 2100, 2100, 2100, 2200, 2200, 2200, 2200, 2200, 2200, 2200, 2200, 2200, 2200, 2200, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2300, 2400, 2400, 2400, 2400, 2400, 2400, 2400, 2400, 2400, 2400, 2400, 2400, 2400, 2400, 2400, 2400, 2400, 2400, 2400, 2400, 2400, 2450, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2550, 2600, 2600, 2600, 2600, 2600, 2600, 2600, 2600, 2600, 2600, 2600, 2600, 2700, 2700, 2700, 2800, 2800, 3200, 3200], "yaxis": "y"}],
#                         {"barmode": "relative", "coloraxis": {"colorbar": {"title": {"text": "Median Period Pay Rate"}}, "colorscale": [[0.0, "LightBlue"], [1.0, "DodgerBlue"]]}, "height": 800, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"line": {"color": "#283442"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"line": {"color": "#283442"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, ...

# %%
# Group by COUNTY and NUMBER of 2020 EMPLOYEES

df_2020 = df[df['Year'] == 2020]

df_county_num = df_2020.groupby('Work County').size().reset_index(name='Number of Employees')
df_county_num = df_county_num.sort_values(by='Number of Employees')

df_county_num = df_county_num.rename(columns = {'Work County':'County'})

df_county_num
# Out:
#       County  Number of Employees
# 32    HARDIN                    2
# 77    PUTNAM                    2
# 75      POPE                    2
# 64    MERCER                    2
# 3      BOONE                    3
# ..       ...                  ...
# 78  RANDOLPH                 1068
# 43  KANKAKEE                 1214
# 98      WILL                 1477
# 15      COOK                 5686
# 82  SANGAMON                 6116
#
# [102 rows x 2 columns]

# %%
# Distribution of Employees by County (2021)

fig5 = px.bar(df_county_num,
              x="County",
              y="Number of Employees",
              template='plotly_dark',
              color='Number of Employees',
              color_continuous_scale = ['LightBlue', 'DodgerBlue'],
              height = 800,
              title = 'Distribution of Workers by County (2021)'
              )

fig5
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6b3c4082-6f39-482a-af5c-b4908f3d6f49" class="plotly-graph-div" style="height:800px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6b3c4082-6f39-482a-af5c-b4908f3d6f49")) {
#                     Plotly.newPlot(
#                         '6b3c4082-6f39-482a-af5c-b4908f3d6f49',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=%{x}<br>Number of Employees=%{marker.color}", "legendgroup": "", "marker": {"color": [2, 2, 2, 2, 3, 3, 4, 5, 6, 7, 7, 8, 8, 9, 9, 9, 9, 9, 9, 10, 10, 10, 11, 11, 11, 11, 12, 12, 12, 14, 14, 14, 15, 16, 17, 17, 18, 20, 21, 22, 22, 25, 25, 28, 33, 33, 33, 35, 36, 38, 43, 47, 47, 52, 56, 68, 71, 75, 89, 106, 118, 129, 134, 134, 156, 166, 167, 192, 196, 231, 237, 281, 285, 285, 291, 296, 324, 335, 342, 345, 350, 362, 381, 383, 395, 418, 429, 469, 507, 554, 577, 688, 744, 758, 790, 820, 974, 1068, 1214, 1477, 5686, 6116], "coloraxis": "coloraxis"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["HARDIN", "PUTNAM", "POPE", "MERCER", "BOONE", "CLAY", "HAMILTON", "SCOTT", "GREENE", "PIATT", "JO DAVIESS", "MENARD", "WAYNE", "HENDERSON", "JASPER", "SHELBY", "MOULTRIE", "STARK", "CLARK", "CUMBERLAND", "CARROLL", "MARSHALL", "PULASKI", "HANCOCK", "WHITE", "BOND", "WOODFORD", "CASS", "MONROE", "ALEXANDER", "WASHINGTON", "FORD", "CALHOUN", "KENDALL", "DE WITT", "GRUNDY", "PIKE", "WABASH", "MCDONOUGH", "DOUGLAS", "IROQUOIS", "OUT OF STATE", "MASON", "OGLE", "WARREN", "BUREAU", "STEPHENSON", "RICHLAND", "MACOUPIN", "MARION", "MASSAC", "EDGAR", "LASALLE", "DE KALB", "MCHENRY", "WHITESIDE", "FRANKLIN", "TAZEWELL", "COLES", "MCLEAN", "EFFINGHAM", "HENRY", "JERSEY", "JACKSON", "SCHUYLER", "CRAWFORD", "WILLIAMSON", "CHRISTIAN", "SALINE", "FAYETTE", "CHAMPAIGN", "WINNEBAGO", "BROWN", "JEFFERSON", "KNOX", "LAWRENCE", "JOHNSON", "VERMILION", "DUPAGE", "MONTGOMERY", "MACON", "FULTON", "PEORIA", "ROCK ISLAND", "PERRY", "ST CLAIR", "ADAMS", "MORGAN", "LAKE", "LA SALLE", "MADISON", "LOGAN", "UNION", "CLINTON", "LEE", "LIVINGSTON", "KANE", "RANDOLPH", "KANKAKEE", "WILL", "COOK", "SANGAMON"], "xaxis": "x", "y": [2, 2, 2, 2, 3, 3, 4, 5, 6, 7, 7, 8, 8, 9, 9, 9, 9, 9, 9, 10, 10, 10, 11, 11, 11, 11, 12, 12, 12, 14, 14, 14, 15, 16, 17, 17, 18, 20, 21, 22, 22, 25, 25, 28, 33, 33, 33, 35, 36, 38, 43, 47, 47, 52, 56, 68, 71, 75, 89, 106, 118, 129, 134, 134, 156, 166, 167, 192, 196, 231, 237, 281, 285, 285, 291, 296, 324, 335, 342, 345, 350, 362, 381, 383, 395, 418, 429, 469, 507, 554, 577, 688, 744, 758, 790, 820, 974, 1068, 1214, 1477, 5686, 6116], "yaxis": "y"}],
#                         {"barmode": "relative", "coloraxis": {"colorbar": {"title": {"text": "Number of Employees"}}, "colorscale": [[0.0, "LightBlue"], [1.0, "DodgerBlue"]]}, "height": 800, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"line": {"color": "#283442"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"line": {"color": "#283442"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "t ...

# %%
# Read in dataset of 2020 population estimates for each Illinois county

df_pop_by_county = pd.read_csv('/content/drive/MyDrive/Spring 2021/BDI-475/Il_pop_by_county.csv')


#Capitalize the names of the counties

df_pop_by_county['County'] = df_pop_by_county['County'].str.upper()


df_pop_by_county.shape
# Out:
# (102, 2)

# %%
import math

# %%
# Merge the two datasets
df_pop_and_county = pd.merge(df_pop_by_county, df_county_num, on='County', how='outer')

# Add column of employees per 1000 residents
df_pop_and_county["Employees per Thousand Residents"] = ((df_pop_and_county["Number of Employees"] / df_pop_and_county["Population"]) * 1000)

# Sort this new column
df_pop_and_county = df_pop_and_county.sort_values(by='Employees per Thousand Residents')

# Drop NaN values (*Doesn't work*) HELP!
# df_pop_and_county = df_pop_and_county[df_pop_and_county['Employees per Thousand Residents'] != math.nan]

df_pop_and_county
# Out:
#            County  ...  Employees per Thousand Residents
# 3           BOONE  ...                          0.048778
# 46        KENDALL  ...                          0.112031
# 65         MERCER  ...                          0.125810
# 55        MCHENRY  ...                          0.162292
# 12           CLAY  ...                          0.227756
# ..            ...  ...                               ...
# 23        EDWARDS  ...                               NaN
# 29       GALLATIN  ...                               NaN
# 102          CASS  ...                               NaN
# 103  OUT OF STATE  ...                               NaN
# 104       LASALLE  ...                               NaN
#
# [105 rows x 4 columns]

# %%
# Distribution of Employees per Thousand Residents by County

fig6 = px.bar(df_pop_and_county,
              x="County",
              y="Employees per Thousand Residents",
              template='plotly_dark',
              color='Employees per Thousand Residents',
              color_continuous_scale = ['LightBlue', 'DodgerBlue'],
              height = 800,
              title = 'State of IL Employees per Thousand Residents by County'
              )

fig6
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="67c166ee-3006-4b69-b20b-42b4b9725b90" class="plotly-graph-div" style="height:800px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("67c166ee-3006-4b69-b20b-42b4b9725b90")) {
#                     Plotly.newPlot(
#                         '67c166ee-3006-4b69-b20b-42b4b9725b90',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "County=%{x}<br>Employees per Thousand Residents=%{marker.color}", "legendgroup": "", "marker": {"color": [0.04877810838495683, 0.11203069641081657, 0.12580990123922753, 0.16229249744968932, 0.22775584573337382, 0.29739776951672864, 0.3037341432910488, 0.3161983919053211, 0.3297609233305853, 0.33344448149383127, 0.36421143432213543, 0.41868254558987716, 0.4319654427645788, 0.4344157525835206, 0.4579803068468056, 0.46580234453846747, 0.47841167324482714, 0.5054653440323498, 0.5065856129685917, 0.5154923872820665, 0.5512638642861868, 0.5628089476003632, 0.5845674201091193, 0.5992264531241488, 0.6116207951070336, 0.6208609271523179, 0.6217455506334033, 0.6338961562842159, 0.6632679092147143, 0.7057661091114406, 0.7136215210950846, 0.7828299301976646, 0.7945967421533572, 0.8199165175909362, 0.8397715821296607, 0.9274717121127806, 0.9296662795814186, 0.9676795045480937, 0.9770395701025891, 0.9797517962116264, 1.0181389491734318, 1.0347206254311336, 1.0408921933085502, 1.0737746336533602, 1.088479114519944, 1.107861177161927, 1.1129660545353368, 1.1516314779270633, 1.2303906490310674, 1.325088339222615, 1.564002499410693, 1.565495769643454, 1.611170784103115, 1.6695635479768112, 1.776672292795594, 1.8406521167499343, 1.8455939693267482, 1.8574854652076749, 1.91659890811941, 1.94688887158321, 2.0239190432382705, 2.075242520139657, 2.123759606607579, 2.160210217471909, 2.3228032917440933, 2.4431277887499085, 2.6744619977609156, 2.6776288652586393, 2.7804070042593465, 2.7864178330741316, 3.048780487804878, 3.320651606720999, 3.5262827600633533, 4.296799846084782, 4.928080272556642, 5.683264059716685, 5.76328923393805, 5.7915057915057915, 6.6264036700081865, 7.265403930965917, 8.202896124550097, 8.652593171748762, 10.113835376532398, 10.12275943066469, 10.36127919977468, 11.66407465007776, 13.298928146089718, 17.55867709815078, 17.94700782150003, 19.588587967748605, 20.817466362020816, 21.663657825302042, 21.904893941494525, 22.646477946017118, 24.019571502705908, 30.053906369010473, 32.84334829940341, 37.61879619852164, 42.86455032551708, null, null, null, null, null, null], "coloraxis": "coloraxis"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["BOONE", "KENDALL", "MERCER", "MCHENRY", "CLAY", "WOODFORD", "GRUNDY", "JO DAVIESS", "MONROE", "PUTNAM", "DUPAGE", "SHELBY", "PIATT", "DE KALB", "POPE", "GREENE", "HAMILTON", "WAYNE", "HARDIN", "OGLE", "TAZEWELL", "MCLEAN", "CLARK", "BOND", "MOULTRIE", "MCDONOUGH", "MENARD", "HANCOCK", "LAKE", "CARROLL", "STEPHENSON", "MACOUPIN", "IROQUOIS", "WHITE", "MARSHALL", "CUMBERLAND", "WINNEBAGO", "SCOTT", "WASHINGTON", "BUREAU", "MARION", "JASPER", "FORD", "DE WITT", "CHAMPAIGN", "COOK", "DOUGLAS", "PIKE", "WHITESIDE", "HENDERSON", "ST CLAIR", "COLES", "STARK", "KANE", "WABASH", "ALEXANDER", "FRANKLIN", "WILL", "WARREN", "MASON", "PULASKI", "PEORIA", "MADISON", "JACKSON", "RICHLAND", "WILLIAMSON", "HENRY", "ROCK ISLAND", "EDGAR", "MASSAC", "CALHOUN", "MACON", "EFFINGHAM", "VERMILION", "LA SALLE", "JERSEY", "KNOX", "CHRISTIAN", "ADAMS", "JEFFERSON", "SALINE", "CRAWFORD", "FAYETTE", "FULTON", "KANKAKEE", "MONTGOMERY", "MORGAN", "PERRY", "LAWRENCE", "CLINTON", "LIVINGSTON", "SCHUYLER", "LEE", "LOGAN", "JOHNSON", "SANGAMON", "RANDOLPH", "BROWN", "UNION", "CASS ", "EDWARDS", "GALLATIN", "CASS", "OUT OF STATE", "LASALLE"], "xaxis": "x", "y": [0.04877810838495683, 0.11203069641081657, 0.12580990123922753, 0.16229249744968932, 0.22775584573337382, 0.29739776951672864, 0.3037341432910488, 0.3161983919053211, 0.3297609233305853, 0.33344448149383127, 0.36421143432213543, 0.41868254558987716, 0.4319654427645788, 0.4344157525835206, 0.4579803068468056, 0.46580234453846747, 0.47841167324482714, 0.5054653440323498, 0.5065856129685917, 0.5154923872820665, 0.5512638642861868, 0.5628089476003632, 0.5845674201091193, 0.5992264531241488, 0.61162079510 ...
#                         {"barmode": "relative", "coloraxis": {"colorbar": {"title": {"text": "Employees per Thousand Residents"}}, "colorscale": [[0.0, "LightBlue"], [1.0, "DodgerBlue"]]}, "height": 800, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [

# %%
print('Restart and run all successful :)')
# Out:
# Restart and run all successful :)
